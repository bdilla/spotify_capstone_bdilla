# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import folium
import requests
from time import sleep
from random import randint
import geopandas as gpd
import geopy
from shapely.geometry import Point
import datetime
from folium.plugins import MarkerCluster
from folium.plugins import FastMarkerCluster

# %matplotlib inline

# %%
us_spotify = pd.read_csv('../data/Spotify Regional Weekly Chart Data/Cleaned Countries/US_spotify_top200_2020.csv')

# %%
us_spotify
# Out:
#        Position                                      Track Name  \
# 0             1                                         The Box
# 1             2                                         ROXANNE
# 2             3                                         Circles
# 3             4                                             BOP
# 4             5                                         Falling
# ...         ...                                             ...
# 10195       196                                            Dior
# 10196       197  If the World Was Ending - feat. Julia Michaels
# 10197       198                                   Electric Love
# 10198       199                            lovely (with Khalid)
# 10199       200                                       Cool Yule
#
#                 Artist     Streams  \
# 0          Roddy Ricch  12533419.0
# 1       Arizona Zervas   9844160.0
# 2          Post Malone   7932216.0
# 3               DaBaby   7560429.0
# ...

# %%
##convert date columns to datetime
us_spotify['Week Beginning'] = pd.to_datetime(us_spotify['Week Beginning'])
us_spotify['Week Ending'] = pd.to_datetime(us_spotify['Week Ending'])

# %%
##adding month column to be able to groupby
us_spotify['Month'] = us_spotify['Week Beginning'].dt.month
us_spotify.head()
# Out:
#    Position Track Name          Artist     Streams  \
# 0         1    The Box     Roddy Ricch  12533419.0
# 1         2    ROXANNE  Arizona Zervas   9844160.0
# 2         3    Circles     Post Malone   7932216.0
# 3         4        BOP          DaBaby   7560429.0
# 4         5    Falling   Trevor Daniel   7197448.0
#
#                                                  URL Week Beginning  \
# 0  https://open.spotify.com/track/0nbXyq5TXYPCO7p...     2019-12-27
# 1  https://open.spotify.com/track/696DnlkuDOXcMAn...     2019-12-27
# 2  https://open.spotify.com/track/21jGcNKet2qwijl...     2019-12-27
# 3  https://open.spotify.com/track/6Ozh9Ok6h4Oi1wU...     2019-12-27
# 4  https://open.spotify.com/track/4TnjEaWOeW0eKTK...     2019-12-27
#
#   Week Ending        Country  Month
# 0  2020-01-03  United States     12
# 1  2020-01-03  United States     12
# 2  2020-01-03  United States     12
# 3  2020-01-03  United States     12
# 4  2020-01-03  United States     12

# %%
us_monthby = us_spotify.groupby('Month').mean().round(0)

# %%
us_monthby = us_monthby.drop(columns=['Position'])
us_monthby
# Out:
#          Streams
# Month
# 1      3091212.0
# 2      3006149.0
# 3      2977771.0
# 4      2573005.0
# 5      2657339.0
# 6      2464568.0
# 7      2894611.0
# 8      2649287.0
# 9      2510098.0
# 10     2448622.0
# 11     2530286.0
# 12     3047635.0

# %%
arg_spotify = pd.read_csv('../data/Spotify Regional Weekly Chart Data/Cleaned Countries/Argentina_spotify_top200_2020.csv')
auz_spotify = pd.read_csv('../data/Spotify Regional Weekly Chart Data/Cleaned Countries/Australia_spotify_top200_2020.csv')
aust_spotify = pd.read_csv('../data/Spotify Regional Weekly Chart Data/Cleaned Countries/Austria_spotify_top200_2020.csv')
can_spotify = pd.read_csv('../data/Spotify Regional Weekly Chart Data/Cleaned Countries/Canada_spotify_top200_2020.csv')
ch_spotify = pd.read_csv('../data/Spotify Regional Weekly Chart Data/Cleaned Countries/Chile_spotify_top200_2020.csv')
ger_spotify = pd.read_csv('../data/Spotify Regional Weekly Chart Data/Cleaned Countries/Germany_spotify_top200_2020.csv')
hk_spotify = pd.read_csv('../data/Spotify Regional Weekly Chart Data/Cleaned Countries/HongKong_spotify_top200_2020.csv')
in_spotify = pd.read_csv('../data/Spotify Regional Weekly Chart Data/Cleaned Countries/India_spotify_top200_2020.csv')
jap_spotify = pd.read_csv('../data/Spotify Regional Weekly Chart Data/Cleaned Countries/Japan_spotify_top200_2020.csv')
mex_spotify = pd.read_csv('../data/Spotify Regional Weekly Chart Data/Cleaned Countries/Mexico_spotify_top200_2020.csv')
nor_spotify = pd.read_csv('../data/Spotify Regional Weekly Chart Data/Cleaned Countries/Norway_spotify_top200_2020.csv')
sa_spotify = pd.read_csv('../data/Spotify Regional Weekly Chart Data/Cleaned Countries/SouthAfrica_spotify_top200_2020.csv')
swz_spotify = pd.read_csv('../data/Spotify Regional Weekly Chart Data/Cleaned Countries/Switzerland_spotify_top200_2020.csv')
swd_spotify = pd.read_csv('../data/Spotify Regional Weekly Chart Data/Cleaned Countries/Sweden_spotify_top200_2020.csv')
sp_spotify = pd.read_csv('../data/Spotify Regional Weekly Chart Data/Cleaned Countries/Spain_spotify_top200_2020.csv')
uk_spotify = pd.read_csv('../data/Spotify Regional Weekly Chart Data/Cleaned Countries/United Kingdom_spotify_top200_2020.csv')

# %%
arg_spotify['Week Beginning'] = pd.to_datetime(arg_spotify['Week Beginning'])
arg_spotify['Week Ending'] = pd.to_datetime(arg_spotify['Week Ending'])
auz_spotify['Week Beginning'] = pd.to_datetime(auz_spotify['Week Beginning'])
auz_spotify['Week Ending'] = pd.to_datetime(auz_spotify['Week Ending'])
aust_spotify['Week Beginning'] = pd.to_datetime(aust_spotify['Week Beginning'])
aust_spotify['Week Ending'] = pd.to_datetime(aust_spotify['Week Ending'])
can_spotify['Week Beginning'] = pd.to_datetime(can_spotify['Week Beginning'])
can_spotify['Week Ending'] = pd.to_datetime(can_spotify['Week Ending'])
ch_spotify['Week Beginning'] = pd.to_datetime(ch_spotify['Week Beginning'])
ch_spotify['Week Ending'] = pd.to_datetime(ch_spotify['Week Ending'])
ger_spotify['Week Beginning'] = pd.to_datetime(ger_spotify['Week Beginning'])
ger_spotify['Week Ending'] = pd.to_datetime(ger_spotify['Week Ending'])
hk_spotify['Week Beginning'] = pd.to_datetime(hk_spotify['Week Beginning'])
hk_spotify['Week Ending'] = pd.to_datetime(hk_spotify['Week Ending'])
in_spotify['Week Beginning'] = pd.to_datetime(in_spotify['Week Beginning'])
in_spotify['Week Ending'] = pd.to_datetime(in_spotify['Week Ending'])
jap_spotify['Week Beginning'] = pd.to_datetime(jap_spotify['Week Beginning'])
jap_spotify['Week Ending'] = pd.to_datetime(jap_spotify['Week Ending'])
mex_spotify['Week Beginning'] = pd.to_datetime(mex_spotify['Week Beginning'])
mex_spotify['Week Ending'] = pd.to_datetime(mex_spotify['Week Ending'])
nor_spotify['Week Beginning'] = pd.to_datetime(nor_spotify['Week Beginning'])
nor_spotify['Week Ending'] = pd.to_datetime(nor_spotify['Week Ending'])
sa_spotify['Week Beginning'] = pd.to_datetime(sa_spotify['Week Beginning'])
sa_spotify['Week Ending'] = pd.to_datetime(sa_spotify['Week Ending'])
swz_spotify['Week Beginning'] = pd.to_datetime(swz_spotify['Week Beginning'])
swz_spotify['Week Ending'] = pd.to_datetime(swz_spotify['Week Ending'])
swd_spotify['Week Beginning'] = pd.to_datetime(swd_spotify['Week Beginning'])
swd_spotify['Week Ending'] = pd.to_datetime(swd_spotify['Week Ending'])
sp_spotify['Week Beginning'] = pd.to_datetime(sp_spotify['Week Beginning'])
sp_spotify['Week Ending'] = pd.to_datetime(sp_spotify['Week Ending'])
uk_spotify['Week Beginning'] = pd.to_datetime(uk_spotify['Week Beginning'])
uk_spotify['Week Ending'] = pd.to_datetime(uk_spotify['Week Ending'])

# %%
arg_spotify['Month'] = arg_spotify['Week Beginning'].dt.month
auz_spotify['Month'] = auz_spotify['Week Beginning'].dt.month
aust_spotify['Month'] = aust_spotify['Week Beginning'].dt.month
can_spotify['Month'] = can_spotify['Week Beginning'].dt.month
ch_spotify['Month'] = ch_spotify['Week Beginning'].dt.month
ger_spotify['Month'] = ger_spotify['Week Beginning'].dt.month
hk_spotify['Month'] = hk_spotify['Week Beginning'].dt.month
in_spotify['Month'] = in_spotify['Week Beginning'].dt.month
jap_spotify['Month'] = jap_spotify['Week Beginning'].dt.month
mex_spotify['Month'] = mex_spotify['Week Beginning'].dt.month
nor_spotify['Month'] = nor_spotify['Week Beginning'].dt.month
sa_spotify['Month'] = sa_spotify['Week Beginning'].dt.month
swz_spotify['Month'] = swz_spotify['Week Beginning'].dt.month
swd_spotify['Month'] = swd_spotify['Week Beginning'].dt.month
sp_spotify['Month'] = sp_spotify['Week Beginning'].dt.month
uk_spotify['Month'] = uk_spotify['Week Beginning'].dt.month

# %%
argartist_totalstream = arg_spotify.groupby('Artist')['Streams'].sum().reset_index()
argartist_totalstream.sort_values('Streams', ascending=False).head(10)
# Out:
#              Artist    Streams
# 21        Bad Bunny  212167811
# 200  Rauw Alejandro  200847765
# 41           Camilo  153180969
# 100        J Balvin  149273294
# 56            Dalex  117659640
# 114         KAROL G  113874006
# 217            Sech  113541643
# 228            TINI  113344624
# 154          Maluma  103349343
# 184           Ozuna   98108189

# %%
arg_monthby = arg_spotify.groupby('Month').mean().round(0)
auz_monthby = auz_spotify.groupby('Month').mean().round(0)
aust_monthby = aust_spotify.groupby('Month').mean().round(0)
can_monthby = can_spotify.groupby('Month').mean().round(0)
ch_monthby = ch_spotify.groupby('Month').mean().round(0)
ger_monthby = ger_spotify.groupby('Month').mean().round(0)
hk_monthby = hk_spotify.groupby('Month').mean().round(0)
in_monthby = in_spotify.groupby('Month').mean().round(0)
jap_monthby = jap_spotify.groupby('Month').mean().round(0)
mex_monthby = mex_spotify.groupby('Month').mean().round(0)
nor_monthby = nor_spotify.groupby('Month').mean().round(0)
sa_monthby = sa_spotify.groupby('Month').mean().round(0)
swz_monthby = swz_spotify.groupby('Month').mean().round(0)
swd_monthby = swd_spotify.groupby('Month').mean().round(0)
sp_monthby = sp_spotify.groupby('Month').mean().round(0)
uk_monthby = uk_spotify.groupby('Month').mean().round(0)

# %%
arg_monthby = arg_monthby.drop(columns=['Position'])
auz_monthby = auz_monthby.drop(columns=['Position'])
aust_monthby = aust_monthby.drop(columns=['Position'])
can_monthby = can_monthby.drop(columns=['Position'])
ch_monthby = ch_monthby.drop(columns=['Position'])
ger_monthby = ger_monthby.drop(columns=['Position'])
hk_monthby = hk_monthby.drop(columns=['Position'])
in_monthby = in_monthby.drop(columns=['Position'])
jap_monthby = jap_monthby.drop(columns=['Position'])
mex_monthby = mex_monthby.drop(columns=['Position'])
nor_monthby = nor_monthby.drop(columns=['Position'])
sa_monthby = sa_monthby.drop(columns=['Position'])
swz_monthby = swz_monthby.drop(columns=['Position'])
swd_monthby = swd_monthby.drop(columns=['Position'])
sp_monthby = sp_monthby.drop(columns=['Position'])
uk_monthby = uk_monthby.drop(columns=['Position'])

# %%
arg_monthby = arg_monthby.rename(columns={"Streams": "arg_avgstream"})
auz_monthby = auz_monthby.rename(columns={"Streams": "auz_avgstream"})
aust_monthby = aust_monthby.rename(columns={"Streams": "aust_avgstream"})
can_monthby = can_monthby.rename(columns={"Streams": "can_avgstream"})
ch_monthby = ch_monthby.rename(columns={"Streams": "ch_avgstream"})
ger_monthby = ger_monthby.rename(columns={"Streams": "ger_avgstream"})
hk_monthby = hk_monthby.rename(columns={"Streams": "hk_avgstream"})
in_monthby = in_monthby.rename(columns={"Streams": "in_avgstream"})
jap_monthby = jap_monthby.rename(columns={"Streams": "jap_avgstream"})
mex_monthby = mex_monthby.rename(columns={"Streams": "mex_avgstream"})
nor_monthby = nor_monthby.rename(columns={"Streams": "nor_avgstream"})
sa_monthby = sa_monthby.rename(columns={"Streams": "sa_avgstream"})
swz_monthby = swz_monthby.rename(columns={"Streams": "swz_avgstream"})
swd_monthby = swd_monthby.rename(columns={"Streams": "swd_avgstream"})
sp_monthby = sp_monthby.rename(columns={"Streams": "sp_avgstream"})
uk_monthby = uk_monthby.rename(columns={"Streams": "uk_avgstream"})

# %%
uk_monthby
# Out:
#        uk_avgstream
# Month
# 1          753609.0
# 2          730909.0
# 3          690362.0
# 4          673499.0
# 5          675678.0
# 6          619111.0
# 7          699217.0
# 8          671681.0
# 9          661384.0
# 10         664730.0
# 11         687544.0
# 12         818825.0
