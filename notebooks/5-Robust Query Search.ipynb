# %%
import base64
import requests
import datetime
from urllib.parse import urlencode

# %%
client_id = 'dd1e7da8e4924986931df06f52c0ab26'
client_secret = '93c91e7a06df4ca6b4984ebbb0c5e891'

# %%
class SpotifyAPI(object):
    access_token = None
    access_token_expires = datetime.datetime.now()
    access_token_did_expire = True
    client_id = None
    client_secret = None
    token_url = "https://accounts.spotify.com/api/token"
    
    def __init__ (self,client_id,client_secret, *args,**kwargs):
        super().__init__(*args, **kwargs)
        self.client_id = client_id
        self.client_secret = client_secret

    def get_client_credentials(self):
        """
        Returns a base64 encoded string
        """
        client_id = self.client_id
        client_secret = self.client_secret
        if client_secret == None or client_id == None:
            raise Exception("You must set client_id and client_secret")
        client_creds = f"{client_id}:{client_secret}"
        client_creds_b64 = base64.b64encode(client_creds.encode())
        return client_creds_b64.decode()

    def get_token_headers(self):
        client_creds_b64 = self.get_client_credentials()
        return {
            "Authorization": f"Basic {client_creds_b64}" 
        } 
    def get_token_data(self):
        return {
            "grant_type":"client_credentials"
        } 

    def perform_auth(self): #method for getting access token
        token_url = self.token_url
        token_data = self.get_token_data()
        token_headers = self.get_token_headers()
        r = requests.post(token_url, data=token_data, headers= token_headers)
        if r.status_code not in range (200,299):
            raise Exception("Could not authenticate client.")
            # return False
        data = r.json()
        now = datetime.datetime.now() #gives the exact time the request is happening
        access_token = data['access_token']
        expires_in =  data['expires_in'] #seconds
        expires = now + datetime.timedelta(seconds=expires_in)#tells you how many seconds your access token expires in so you know when you renew your access_token
        self.access_token = access_token
        self.access_token_expires = expires
        self.access_token_did_expire = expires < now  #gives boolean response with whether or not token is expired
        return True
    
    def get_access_token(self):
        #auth_done = self.perform_auth()
        #if not auth_done:
         #   raise Exception("Authentication failed")
        token = self.access_token
        expires = self.access_token_expires
        now = datetime.datetime.now()
        if expires < now:
            self.perform_auth()
            return self.get_access_token()
        elif token == None:
            self.perform_auth()
            return self.get_access_token()
        return token
    
    def get_resource_header(self):
        access_token = self.get_access_token()
        headers = {
            "Authorization":f"Bearer {access_token}"
        }
        return headers
    
    def get_resource(self, lookup_id, resource_type='albums', version = 'v1'):
        endpoint = f"https://api.spotify.com/{version}/{resource_type}/{lookup_id}"
        headers = self.get_resource_header()
        r = requests.get(endpoint, headers=headers)
        if r.status_code not in range(200,299):
            return{}
        return r.json()
        
    def get_album(self, _id):
        return self.get_resource(_id, resource_type='albums')
    
    def get_artist(self, _id):
        return self.get_resource(_id, resource_type='artists')
    
    
    def base_search(self, query_params): #type
        headers = self.get_resource_header()
        endpoint = "https://api.spotify.com/v1/search"
        lookup_url = f"{endpoint}?{query_params}"
        print(lookup_url)
        r = requests.get(lookup_url, headers=headers)
        if r.status_code not in range(200,299):
            return {}
        return r.json()
    
    def search(self, query=None, operator=None, operator_query=None, search_type='artist'):
        if query == None:
            raise Exception ("A query is required")
        if isinstance(query,dict):
                query = " ".join([f"{k}:{v}" for k,v in query.items()])
        if operator != None and operator_query != None:
            if operator.lower() == "or" or operator.lower() == "not":
                operator = operator.upper()
                if isinstance(operator_query,str):
                    query = f"{query} {operator} {operator_query}"
        query_params = urlencode({"q":query, "type": search_type.lower()}) ##encodes spaces
        print(query_params)
        return self.base_search(query_params)

# %%
spotify = SpotifyAPI(client_id, client_secret)

# %%
spotify.search({"track":"A lannister always pays his debts", "artist":"Ramin"}, search_type="artist")
# Out:
# q=track%3AA+lannister+always+pays+his+debts+artist%3ARamin&type=artist
# https://api.spotify.com/v1/search?q=track%3AA+lannister+always+pays+his+debts+artist%3ARamin&type=artist
# {'artists': {'href': 'https://api.spotify.com/v1/search?query=track%3AA+lannister+always+pays+his+debts+artist%3ARamin&type=artist&offset=0&limit=20',
#   'items': [],
#   'limit': 20,
#   'next': None,
#   'offset': 0,
#   'previous': None,
#   'total': 0}}

# %%
spotify.search(query = "Danger Zone", search_type="track")
# Out:
# q=Danger+Zone&type=track
# https://api.spotify.com/v1/search?q=Danger+Zone&type=track
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=Danger+Zone&type=track&offset=0&limit=20',
#   'items': [{'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3Y3xIwWyq5wnNHPp5gPjOW'},
#        'href': 'https://api.spotify.com/v1/artists/3Y3xIwWyq5wnNHPp5gPjOW',
#        'id': '3Y3xIwWyq5wnNHPp5gPjOW',
#        'name': 'Kenny Loggins',
#        'type': 'artist',
#        'uri': 'spotify:artist:3Y3xIwWyq5wnNHPp5gPjOW'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3uN87hwClF0hult2cxMbAW'},
#      'href': 'https://api.spotify.com/v1/albums/3uN87hwClF0hult2cxMbAW',
#      'id': '3uN87hwClF0hult2cxMbAW',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27319db9ac54c80a898a179f0f1',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0219db9ac54c80a898a179f0f1',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485119db9ac54c80a898a179f0f1',
#        'width': 64}],
#      'name': 'Yesterday, Today, Tomorrow - The Greatest Hits Of Kenny Loggins',
#      'release_date': '1997-03-25',
#      'release_date_precision': 'day',
#      'total_tracks': 15,
#      'type': 'album',
#      'uri': 'spotify:album:3uN87hwClF0hult2cxMbAW'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3Y3xIwWyq5wnNHPp5gPjOW'},
#       'href': 'https://api.spotify.com/v1/artists/3Y3xIwWyq5wnNHPp5gPjOW',
#       'id': '3Y3xIwWyq5wnNHPp5gPjOW',
#       'name': 'Kenny Loggins',
#       'type': 'artist',
#       'uri': 'spotify:artist:3Y3xIwWyq5wnNHPp5gPjOW'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 215133,
#     'explicit': False,
#     'external_ids': {'isrc': 'USSM18600108'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/34x6hEJgGAOQvmlMql5Ige'},
#     'href': 'https://api.spotify.com/v1/tracks/34x6hEJgGAOQvmlMql5Ige',
#     'id': '34x6hEJgGAOQvmlMql5Ige',
#     'is_local': False,
#     'name': 'Danger Zone - From "Top Gun" Original Soundtrack',
#     'popularity': 72,
#     'preview_url': 'https://p.scdn.co/mp3-preview/37f82469e33bd437dd5b313796a6f7230d4dbd01?cid=dd1e7da8e4924986931df06f52c0ab26',
#     'track_number': 5,
#     'type': 'track',
#     'uri': 'spotify:track:34x6hEJgGAOQvmlMql5Ige'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2kfVqdz3lJshqH9GUHhtMr'},
#        'href': 'https://api.spotify.com/v1/artists/2kfVqdz3lJshqH9GUHhtMr',
#        'id': '2kfVqdz3lJshqH9GUHhtMr',
#        'name': 'Psychostick',
#        'type': 'artist',
#        'uri': 'spotify:artist:2kfVqdz3lJshqH9GUHhtMr'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1GIf6jw4y0wh8mdf9kclPK'},
#      'href': 'https://api.spotify.com/v1/albums/1GIf6jw4y0wh8mdf9kclPK',
#      'id': '1GIf6jw4y0wh8mdf9kclPK',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2738efd97fa8c93bccf7ff9aa1a',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e028efd97fa8c93bccf7ff9aa1a',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048518efd97fa8c93bccf7ff9aa1a',
#        'width': 64}],
#      'name': 'IV: Revenge of the Vengeance',
#      'release_date': '2014-11-04',
#      'release_date_precision': 'day',
#      'total_tracks': 18,
#      'type': 'album',
#      'uri': 'spotify:album:1GIf6jw4y0wh8mdf9kclPK'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2kfVqdz3lJshqH9GUHhtMr'},
#       'href': 'https://api.spotify.com/v1/artists/2kfVqdz3lJshqH9GUHhtMr',
#       'id': '2kfVqdz3lJshqH9GUHhtMr',
#       'name': 'Psychostick',
#       'type': 'artist',
#       'uri': 'spotify:artist:2kfVqdz3lJshqH9GUHhtMr'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 230000,
#     'explicit': False,
#     'external_ids': {'isrc': 'USB761402574'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2nLq4qdtLXZnVllYlQ0WJn'},
#     'href': 'https://api.spotify.com/v1/tracks/2nLq4qdtLXZnVllYlQ0WJn',
#     'id': '2nLq4qdtLXZnVllYlQ0WJn',
#     'is_local': False,
#     'name': 'Danger Zone',
#     'popularity': 45,
#     'preview_url': 'https://p.scdn.co/mp3-preview/5e87d27d0448bf2c8b0d5583957709be429e9c8c?cid=dd1e7da8e4924986931df06f52c0ab26',
#     'track_number': 10,
#     'type': 'track',
#     'uri': 'spotify:track:2nLq4qdtLXZnVllYlQ0WJn'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/30fiiwr2EeZp1tAhzYCmyM'},
#        'href': 'https://api.spotify.com/v1/artists/30fiiwr2EeZp1tAhzYCmyM',
#        'id': '30fiiwr2EeZp1tAhzYCmyM',
#        'name': 'Big L',
#        'type': 'artist',
#        'uri': 'spotify:artist:30fiiwr2EeZp1tAhzYCmyM'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7xvBUHu5jJ7X0wdRHudLFD'},
#      'href': 'https://api.spotify.com/v1/albums/7xvBUHu5jJ7X0wdRHudLFD',
#      'id': '7xvBUHu5jJ7X0wdRHudLFD',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273f22da4550a4de3cefb5afc0b',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02f22da4550a4de3cefb5afc0b',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851f22da4550a4de3cefb5afc0b',
#        'width': 64}],
#      'name': 'Lifestylez Ov Da Poor & Dangerous',
#      'release_date': '1995-03-28',
#      'release_date_precision': 'day',
#      'total_tracks': 12,
#      'type': 'album',
#      'uri': 'spotify:album:7xvBUHu5jJ7X0wdRHudLFD'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/30fiiwr2EeZp1tAhzYCmyM'},
#       'href': 'https://api.spotify.com/v1/artists/30fiiwr2EeZp1tAhzYCmyM',
#       'id': '30fiiwr2EeZp1tAhzYCmyM',
#       'name': 'Big L',
#       'type': 'artist',
#       'uri': 'spotify:artist:30fiiwr2EeZp1tAhzYCmyM'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 216600,
#     'explicit': True,
#     'external_ids': {'isrc': 'USSM10022974'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0kU9oWqYnPeqEca3x2auV9'},
#     'href': 'https://api.spotify.com/v1/tracks/0kU9oWqYnPeqEca3x2auV9',
#     'id': '0kU9oWqYnPeqEca3x2auV9',
#     'is_local': False,
#     'name': 'Danger Zone',
#     'popularity': 43,
#     'preview_url': 'https://p.scdn.co/mp3-preview/495847449bde33b99caf856246227baa9e168126?cid=dd1e7da8e4924986931df06f52c0ab26',
#     'track_number': 6,
#     'type': 'track',
#     'uri': 'spotify:track:0kU9oWqYnPeqEca3x2auV9'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0oCxVgCMY7h0OHpSg3Hu90'},
#        'href': 'https://api.spotify.com/v1/artists/0oCxVgCMY7h0OHpSg3Hu90',
#        'id': '0oCxVgCMY7h0OHpSg3Hu90',
#        'name': 'Apollo Delphi',
#        'type': 'artist',
#        'uri': 'spotify:artist:0oCxVgCMY7h0OHpSg3Hu90'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5lhinvo0L6pqmwcxQM5Gce'},
#      'href': 'https://api.spotify.com/v1/albums/5lhinvo0L6pqmwcxQM5Gce',
#      'id': '5lhinvo0L6pqmwcxQM5Gce',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273ca626e4da8774283639c0051',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02ca626e4da8774283639c0051',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851ca626e4da8774283639c0051',
#        'width': 64}],
#      'name': 'Danger Zone',
#      'release_date': '2020-10-30',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:5lhinvo0L6pqmwcxQM5Gce'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0oCxVgCMY7h0OHpSg3Hu90'},
#       'href': 'https://api.spotify.com/v1/artists/0oCxVgCMY7h0OHpSg3Hu90',
#       'id': '0oCxVgCMY7h0OHpSg3Hu90',
#       'name': 'Apollo Delphi',
#       'type': 'artist',
#       'uri': 'spotify:artist:0oCxVgCMY7h0OHpSg3Hu90'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/3MR4txOkZUPgjFe9gnKQ1D'},
#       'href': 'https://api.spotify.com/v1/artists/3MR4txOkZUPgjFe9gnKQ1D',
#       'id': '3MR4txOkZUPgjFe9gnKQ1D',
#       'name': 'Nef Ryder',
#       'type': 'artist',
#       'uri': 'spotify:artist:3MR4txOkZUPgjFe9gnKQ1D'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 162303,
#     'explicit': True,
#     'external_ids': {'isrc': 'QZ6RV2000001'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/65MieTyL5yDv6jSAbOGQiz'},
#     'href': 'https://api.spotify.com/v1/tracks/65MieTyL5yDv6jSAbOGQiz',
#     'id': '65MieTyL5yDv6jSAbOGQiz',
#     'is_local': False,
#     'name': 'Danger Zone',
#     'popularity': 34,
#     'preview_url': 'https://p.scdn.co/mp3-preview/0ffed09ee92a69504000917c81d152714ed54190?cid=dd1e7da8e4924986931df06f52c0ab26',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:65MieTyL5yDv6jSAbOGQiz'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0vDwx0CU6ln0giCDLK6k8D'},
#        'href': 'https://api.spotify.com/v1/artists/0vDwx0CU6ln0giCDLK6k8D',
#        'id': '0vDwx0CU6ln0giCDLK6k8D',
#        'name': 'Cherlene',
#        'type': 'artist',
#        'uri': 'spotify:artist:0vDwx0CU6ln0giCDLK6k8D'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4PIrTzsajipA45y7Uvg9X0'},
#      'href': 'https://api.spotify.com/v1/albums/4PIrTzsajipA45y7Uvg9X0',
#      'id': '4PIrTzsajipA45y7Uvg9X0',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2731d9a4d2294f9560c5a9b1878',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e021d9a4d2294f9560c5a9b1878',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048511d9a4d2294f9560c5a9b1878',
#        'width': 64}],
#      'name': 'Archer: Cherlene (Songs from the TV Series)',
#      'release_date': '2014-01-13',
#      'release_date_precision': 'day',
#      'total_tracks': 12,
#      'type': 'album',
#      'uri': 'spotify:album:4PIrTzsajipA45y7Uvg9X0'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0vDwx0CU6ln0giCDLK6k8D'},
#       'href': 'https://api.spotify.com/v1/artists/0vDwx0CU6ln0giCDLK6k8D',
#       'id': '0vDwx0CU6ln0giCDLK6k8D',
#       'name': 'Cherlene',
#       'type': 'artist',
#       'uri': 'spotify:artist:0vDwx0CU6ln0giCDLK6k8D'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/3Y3xIwWyq5wnNHPp5gPjOW'},
#       'href': 'https://api.spotify.com/v1/artists/3Y3xIwWyq5wnNHPp5gPjOW',
#       'id': '3Y3xIwWyq5wnNHPp5gPjOW',
#       'name': 'Kenny Loggins',
#       'type': 'artist',
#       'uri': 'spotify:artist:3Y3xIwWyq5wnNHPp5gPjOW'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 221189,
#     'explicit': False,
#     'external_ids': {'isrc': 'USFM91400002'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/50J6XwEbkYxNb5e4k6R9s1'},
#     'href': 'https://api.spotify.com/v1/tracks/50J6XwEbkYxNb5e4k6R9s1',
#     'id': '50J6XwEbkYxNb5e4k6R9s1',
#     'is_local': False,
#     'name': 'Danger Zone',
#     'popularity': 39,
#     'preview_url': None,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:50J6XwEbkYxNb5e4k6R9s1'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4yiQZ8tQPux8cPriYMWUFP'},
#        'href': 'https://api.spotify.com/v1/artists/4yiQZ8tQPux8cPriYMWUFP',
#        'id': '4yiQZ8tQPux8cPriYMWUFP',
#        'name': 'Gwen Stefani',
#        'type': 'artist',
#        'uri': 'spotify:artist:4yiQZ8tQPux8cPriYMWUFP'}],
#      'available_markets': ['AD',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'EC',
#       'EE',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JP',
#       'KZ',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'RO',
#       'RS',
#       'RU',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3Lqn8M0QxPLIPRJ4nUKTGN'},
#      'href': 'https://api.spotify.com/v1/albums/3Lqn8M0QxPLIPRJ4nUKTGN',
#      'id': '3Lqn8M0QxPLIPRJ4nUKTGN',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2737c7136a182372ccdffb3d3c4',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e027c7136a182372ccdffb3d3c4',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048517c7136a182372ccdffb3d3c4',
#        'width': 64}],
#      'name': 'Love Angel Music Baby (Deluxe Version)',
#      'release_date': '2004-11-23',
#      'release_date_precision': 'day',
#      'total_tracks': 20,
#      'type': 'album',
#      'uri': 'spotify:album:3Lqn8M0QxPLIPRJ4nUKTGN'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4yiQZ8tQPux8cPriYMWUFP'},
#       'href': 'https://api.spotify.com/v1/artists/4yiQZ8tQPux8cPriYMWUFP',
#       'id': '4yiQZ8tQPux8cPriYMWUFP',
#       'name': 'Gwen Stefani',
#       'type': 'artist',
#       'uri': 'spotify:artist:4yiQZ8tQPux8cPriYMWUFP'}],
#     'available_markets': ['AD',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'EC',
#      'EE',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JP',
#      'KZ',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'RO',
#      'RS',
#      'RU',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 216800,
#     'explicit': False,
#     'external_ids': {'isrc': 'USIR10400849'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0wGcnSwFNCv9RFIMhO4ao2'},
#     'href': 'https://api.spotify.com/v1/tracks/0wGcnSwFNCv9RFIMhO4ao2',
#     'id': '0wGcnSwFNCv9RFIMhO4ao2',
#     'is_local': False,
#     'name': 'Danger Zone',
#     'popularity': 33,
#     'preview_url': None,
#     'track_number': 11,
#     'type': 'track',
#     'uri': 'spotify:track:0wGcnSwFNCv9RFIMhO4ao2'},
#    {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#        'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#        'id': '0LyfQWJT6nXafLPZqxe9Of',
#        'name': 'Various Artists',
#        'type': 'artist',
#        'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#      'available_markets': ['US'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2zmq7HA083bUUqagbwKzEf'},
#      'href': 'https://api.spotify.com/v1/albums/2zmq7HA083bUUqagbwKzEf',
#      'id': '2zmq7HA083bUUqagbwKzEf',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273bc114bcd8e533beec77df770',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02bc114bcd8e533beec77df770',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851bc114bcd8e533beec77df770',
#        'width': 64}],
#      'name': '17 Again (Music From The Motion Picture)',
#      'release_date': '2009-04-14',
#      'release_date_precision': 'day',
#      'total_tracks': 14,
#      'type': 'album',
#      'uri': 'spotify:album:2zmq7HA083bUUqagbwKzEf'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3Y3xIwWyq5wnNHPp5gPjOW'},
#       'href': 'https://api.spotify.com/v1/artists/3Y3xIwWyq5wnNHPp5gPjOW',
#       'id': '3Y3xIwWyq5wnNHPp5gPjOW',
#       'name': 'Kenny Loggins',
#       'type': 'artist',
#       'uri': 'spotify:artist:3Y3xIwWyq5wnNHPp5gPjOW'}],
#     'available_markets': ['US'],
#     'disc_number': 1,
#     'duration_ms': 216666,
#     'explicit': False,
#     'external_ids': {'isrc': 'USSM19904142'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1xEg4DqjDUpNNl9kOL75xg'},
#     'href': 'https://api.spotify.com/v1/tracks/1xEg4DqjDUpNNl9kOL75xg',
#     'id': '1xEg4DqjDUpNNl9kOL75xg',
#     'is_local': False,
#     'name': 'Danger Zone',
#     'popularity': 30,
#     'preview_url': 'https://p.scdn.co/mp3-preview/4f453f4ff7df32965fa592a16834fe30dc9ac51e?cid=dd1e7da8e4924986931df06f52c0ab26',
#     'track_number': 13,
#     'type': 'track',
#     'uri': 'spotify:track:1xEg4DqjDUpNNl9kOL75xg'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2rVDi66o7gdeUq1OHUzM0W'},
#        'href': 'https://api.spotify.com/v1/artists/2rVDi66o7gdeUq1OHUzM0W',
#        'id': '2rVDi66o7gdeUq1OHUzM0W',
#        'name': 'The Protomen',
#        'type': 'artist',
#        'uri': 'spotify:artist:2rVDi66o7gdeUq1OHUzM0W'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2alFG2VsPE8xiozFQz3A0i'},
#      'href': 'https://api.spotify.com/v1/albums/2alFG2VsPE8xiozFQz3A0i',
#      'id': '2alFG2VsPE8xiozFQz3A0i',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273491b4c374353dcd9f60701cd',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02491b4c374353dcd9f60701cd',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851491b4c374353dcd9f60701cd',
#        'width': 64}],
#      'name': 'The Cover Up (Original Motion Picture Soundtrack)',
#      'release_date': '2015-02-20',
#      'release_date_precision': 'day',
#      'total_tracks': 15,
#      'type': 'album',
#      'uri': 'spotify:album:2alFG2VsPE8xiozFQz3A0i'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2rVDi66o7gdeUq1OHUzM0W'},
#       'href': 'https://api.spotify.com/v1/artists/2rVDi66o7gdeUq1OHUzM0W',
#       'id': '2rVDi66o7gdeUq1OHUzM0W',
#       'name': 'The Protomen',
#       'type': 'artist',
#       'uri': 'spotify:artist:2rVDi66o7gdeUq1OHUzM0W'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 244253,
#     'explicit': False,
#     'external_ids': {'isrc': 'TCACD1546249'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0XhcbuMPBRRcaqRiHMrnKl'},
#     'href': 'https://api.spotify.com/v1/tracks/0XhcbuMPBRRcaqRiHMrnKl',
#     'id': '0XhcbuMPBRRcaqRiHMrnKl',
#     'is_local': False,
#     'name': 'Danger Zone',
#     'popularity': 32,
#     'preview_url': 'https://p.scdn.co/mp3-preview/00c45f77951adbca891f1fbe7c24a9d4d0011303?cid=dd1e7da8e4924986931df06f52c0ab26',
#     'track_number': 14,
#     'type': 'track',
#     'uri': 'spotify:track:0XhcbuMPBRRcaqRiHMrnKl'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2KaW48xlLnXC2v8tvyhWsa'},
#        'href': 'https://api.spotify.com/v1/artists/2KaW48xlLnXC2v8tvyhWsa',
#        'id': '2KaW48xlLnXC2v8tvyhWsa',
#        'name': 'Amaranthe',
#        'type': 'artist',
#        'uri': 'spotify:artist:2KaW48xlLnXC2v8tvyhWsa'}],
#      'available_markets': ['AD',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'EC',
#       'EE',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'KZ',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'PY',
#       'RO',
#       'RS',
#       'RU',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0GCcO9StyRRAGumjCOTSpN'},
#      'href': 'https://api.spotify.com/v1/albums/0GCcO9StyRRAGumjCOTSpN',
#      'id': '0GCcO9StyRRAGumjCOTSpN',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2737e1fea351d3673f4f94f5c8c',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e027e1fea351d3673f4f94f5c8c',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048517e1fea351d3673f4f94f5c8c',
#        'width': 64}],
#      'name': 'MASSIVE ADDICTIVE',
#      'release_date': '2014-10-17',
#      'release_date_precision': 'day',
#      'total_tracks': 13,
#      'type': 'album',
#      'uri': 'spotify:album:0GCcO9StyRRAGumjCOTSpN'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2KaW48xlLnXC2v8tvyhWsa'},
#       'href': 'https://api.spotify.com/v1/artists/2KaW48xlLnXC2v8tvyhWsa',
#       'id': '2KaW48xlLnXC2v8tvyhWsa',
#       'name': 'Amaranthe',
#       'type': 'artist',
#       'uri': 'spotify:artist:2KaW48xlLnXC2v8tvyhWsa'}],
#     'available_markets': ['AD',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'EC',
#      'EE',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'KZ',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'PY',
#      'RO',
#      'RS',
#      'RU',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 181573,
#     'explicit': False,
#     'external_ids': {'isrc': 'FIUM71400491'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7kkNY7oiD6O1LliNRVN45A'},
#     'href': 'https://api.spotify.com/v1/tracks/7kkNY7oiD6O1LliNRVN45A',
#     'id': '7kkNY7oiD6O1LliNRVN45A',
#     'is_local': False,
#     'name': 'Danger Zone',
#     'popularity': 38,
#     'preview_url': None,
#     'track_number': 9,
#     'type': 'track',
#     'uri': 'spotify:track:7kkNY7oiD6O1LliNRVN45A'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1co4F2pPNH8JjTutZkmgSm'},
#        'href': 'https://api.spotify.com/v1/artists/1co4F2pPNH8JjTutZkmgSm',
#        'id': '1co4F2pPNH8JjTutZkmgSm',
#        'name': 'Ramones',
#        'type': 'artist',
#        'uri': 'spotify:artist:1co4F2pPNH8JjTutZkmgSm'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4szj932hnsBBNAfKwXAIKD'},
#      'href': 'https://api.spotify.com/v1/albums/4szj932hnsBBNAfKwXAIKD',
#      'id': '4szj932hnsBBNAfKwXAIKD',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273b273e56214705cc3f292f44e',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02b273e56214705cc3f292f44e',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851b273e56214705cc3f292f44e',
#        'width': 64}],
#      'name': 'Too Tough to Die (Expanded 2005 Remaster)',
#      'release_date': '1984-10-01',
#      'release_date_precision': 'day',
#      'total_tracks': 25,
#      'type': 'album',
#      'uri': 'spotify:album:4szj932hnsBBNAfKwXAIKD'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1co4F2pPNH8JjTutZkmgSm'},
#       'href': 'https://api.spotify.com/v1/artists/1co4F2pPNH8JjTutZkmgSm',
#       'id': '1co4F2pPNH8JjTutZkmgSm',
#       'name': 'Ramones',
#       'type': 'artist',
#       'uri': 'spotify:artist:1co4F2pPNH8JjTutZkmgSm'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 128400,
#     'explicit': False,
#     'external_ids': {'isrc': 'USWB10201762'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4ftS7lkyqKQ3KtVdCnmINL'},
#     'href': 'https://api.spotify.com/v1/tracks/4ftS7lkyqKQ3KtVdCnmINL',
#     'id': '4ftS7lkyqKQ3KtVdCnmINL',
#     'is_local': False,
#     'name': 'Danger Zone - 2002 Remaster',
#     'popularity': 41,
#     'preview_url': 'https://p.scdn.co/mp3-preview/9a15593d5330c8bed7a959a7dfdfadfdf06cf1e6?cid=dd1e7da8e4924986931df06f52c0ab26',
#     'track_number': 6,
#     'type': 'track',
#     'uri': 'spotify:track:4ftS7lkyqKQ3KtVdCnmINL'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/46Eat3ICRRjwmIgSYKbGMk'},
#        'href': 'https://api.spotify.com/v1/artists/46Eat3ICRRjwmIgSYKbGMk',
#        'id': '46Eat3ICRRjwmIgSYKbGMk',
#        'name': 'Treazy Beats',
#        'type': 'artist',
#        'uri': 'spotify:artist:46Eat3ICRRjwmIgSYKbGMk'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0tuHyKkwqFAZUah7K9LkC8'},
#      'href': 'https://api.spotify.com/v1/albums/0tuHyKkwqFAZUah7K9LkC8',
#      'id': '0tuHyKkwqFAZUah7K9LkC8',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273e9623bb6c895ca509cc866db',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02e9623bb6c895ca509cc866db',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851e9623bb6c895ca509cc866db',
#        'width': 64}],
#      'name': 'Danger Zone',
#      'release_date': '2020-11-05',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:0tuHyKkwqFAZUah7K9LkC8'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/46Eat3ICRRjwmIgSYKbGMk'},
#       'href': 'https://api.spotify.com/v1/artists/46Eat3ICRRjwmIgSYKbGMk',
#       'id': '46Eat3ICRRjwmIgSYKbGMk',
#       'name': 'Treazy Beats',
#       'type': 'artist',
#       'uri': 'spotify:artist:46Eat3ICRRjwmIgSYKbGMk'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 72322,
#     'explicit': False,
#     'external_ids': {'isrc': 'QZNJW2007603'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/44kFOrsjJ3aRY8qQCh3ZdX'},
#     'href': 'https://api.spotify.com/v1/tracks/44kFOrsjJ3aRY8qQCh3ZdX',
#     'id': '44kFOrsjJ3aRY8qQCh3ZdX',
#     'is_local': False,
#     'name': 'Danger Zone',
#     'popularity': 37,
#     'preview_url': 'https://p.scdn.co/mp3-preview/c02e7c2a89dc26ab977b048a1e15ff2be51fb780?cid=dd1e7da8e4924986931df06f52c0ab26',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:44kFOrsjJ3aRY8qQCh3ZdX'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5a1N0XeGODSepJKFoMK9oq'},
#        'href': 'https://api.spotify.com/v1/artists/5a1N0XeGODSepJKFoMK9oq',
#        'id': '5a1N0XeGODSepJKFoMK9oq',
#        'name': 'Terano',
#        'type': 'artist',
#        'uri': 'spotify:artist:5a1N0XeGODSepJKFoMK9oq'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3r9plnNinzOcFK2ps4KyNw'},
#      'href': 'https://api.spotify.com/v1/albums/3r9plnNinzOcFK2ps4KyNw',
#      'id': '3r9plnNinzOcFK2ps4KyNw',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273533c583fef8f36fb60ccb86d',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02533c583fef8f36fb60ccb86d',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851533c583fef8f36fb60ccb86d',
#        'width': 64}],
#      'name': 'Danger Zone',
#      'release_date': '2020-07-18',
#      'release_date_precision': 'day',
#      'total_tracks': 10,
#      'type': 'album',
#      'uri': 'spotify:album:3r9plnNinzOcFK2ps4KyNw'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5a1N0XeGODSepJKFoMK9oq'},
#       'href': 'https://api.spotify.com/v1/artists/5a1N0XeGODSepJKFoMK9oq',
#       'id': '5a1N0XeGODSepJKFoMK9oq',
#       'name': 'Terano',
#       'type': 'artist',
#       'uri': 'spotify:artist:5a1N0XeGODSepJKFoMK9oq'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
# ...
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 172500,
#     'explicit': False,
#     'external_ids': {'isrc': 'SE5IB1900484'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/48gfj7REhcvZjASWAPEo68'},
#     'href': 'https://api.spotify.com/v1/tracks/48gfj7REhcvZjASWAPEo68',
#     'id': '48gfj7REhcvZjASWAPEo68',
#     'is_local': False,
#     'name': 'Danger Zone',
#     'popularity': 35,
#     'preview_url': 'https://p.scdn.co/mp3-preview/368e7c850ab6ddfb006f5ae757199c5ada1d109d?cid=dd1e7da8e4924986931df06f52c0ab26',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:48gfj7REhcvZjASWAPEo68'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2ny8O1x4bkp9dSq4OCic3o'},
#        'href': 'https://api.spotify.com/v1/artists/2ny8O1x4bkp9dSq4OCic3o',
#        'id': '2ny8O1x4bkp9dSq4OCic3o',
#        'name': 'M3NACE',
#        'type': 'artist',
#        'uri': 'spotify:artist:2ny8O1x4bkp9dSq4OCic3o'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6ULRftiNtyZqBzBu8Hj7iC'},
#      'href': 'https://api.spotify.com/v1/albums/6ULRftiNtyZqBzBu8Hj7iC',
#      'id': '6ULRftiNtyZqBzBu8Hj7iC',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273cf9b01ae1d6b86cff3bd3221',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02cf9b01ae1d6b86cff3bd3221',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851cf9b01ae1d6b86cff3bd3221',
#        'width': 64}],
#      'name': 'Danger Zone EP',
#      'release_date': '2020-12-02',
#      'release_date_precision': 'day',
#      'total_tracks': 3,
#      'type': 'album',
#      'uri': 'spotify:album:6ULRftiNtyZqBzBu8Hj7iC'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2ny8O1x4bkp9dSq4OCic3o'},
#       'href': 'https://api.spotify.com/v1/artists/2ny8O1x4bkp9dSq4OCic3o',
#       'id': '2ny8O1x4bkp9dSq4OCic3o',
#       'name': 'M3NACE',
#       'type': 'artist',
#       'uri': 'spotify:artist:2ny8O1x4bkp9dSq4OCic3o'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 219200,
#     'explicit': True,
#     'external_ids': {'isrc': 'QZMER2063469'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5sRPNlMRJFCoOiVv3vZtcT'},
#     'href': 'https://api.spotify.com/v1/tracks/5sRPNlMRJFCoOiVv3vZtcT',
#     'id': '5sRPNlMRJFCoOiVv3vZtcT',
#     'is_local': False,
#     'name': 'DANGER ZONE',
#     'popularity': 28,
#     'preview_url': 'https://p.scdn.co/mp3-preview/e625d04dbdf530ed22bfb16766f527c855a100f4?cid=dd1e7da8e4924986931df06f52c0ab26',
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:5sRPNlMRJFCoOiVv3vZtcT'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/65T6BIrUTcgylCYTXqVxvR'},
#        'href': 'https://api.spotify.com/v1/artists/65T6BIrUTcgylCYTXqVxvR',
#        'id': '65T6BIrUTcgylCYTXqVxvR',
#        'name': 'Baker Ya Maker',
#        'type': 'artist',
#        'uri': 'spotify:artist:65T6BIrUTcgylCYTXqVxvR'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5m8VnHwpH9YcAcY4TNmslX'},
#      'href': 'https://api.spotify.com/v1/albums/5m8VnHwpH9YcAcY4TNmslX',
#      'id': '5m8VnHwpH9YcAcY4TNmslX',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2733f20ab26bc95e9f438d35385',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e023f20ab26bc95e9f438d35385',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048513f20ab26bc95e9f438d35385',
#        'width': 64}],
#      'name': 'Greates Hits, Pt. 1',
#      'release_date': '2018-10-24',
#      'release_date_precision': 'day',
#      'total_tracks': 13,
#      'type': 'album',
#      'uri': 'spotify:album:5m8VnHwpH9YcAcY4TNmslX'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/65T6BIrUTcgylCYTXqVxvR'},
#       'href': 'https://api.spotify.com/v1/artists/65T6BIrUTcgylCYTXqVxvR',
#       'id': '65T6BIrUTcgylCYTXqVxvR',
#       'name': 'Baker Ya Maker',
#       'type': 'artist',
#       'uri': 'spotify:artist:65T6BIrUTcgylCYTXqVxvR'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 196418,
#     'explicit': True,
#     'external_ids': {'isrc': 'QZES61801785'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2c1MoaYcylTXwG588SYh8j'},
#     'href': 'https://api.spotify.com/v1/tracks/2c1MoaYcylTXwG588SYh8j',
#     'id': '2c1MoaYcylTXwG588SYh8j',
#     'is_local': False,
#     'name': 'Danger Zone',
#     'popularity': 27,
#     'preview_url': 'https://p.scdn.co/mp3-preview/6d127da1d92515bb8db9674c2653fe89b662e5ab?cid=dd1e7da8e4924986931df06f52c0ab26',
#     'track_number': 9,
#     'type': 'track',
#     'uri': 'spotify:track:2c1MoaYcylTXwG588SYh8j'},
#    {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#        'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#        'id': '0LyfQWJT6nXafLPZqxe9Of',
#        'name': 'Various Artists',
#        'type': 'artist',
#        'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/75qfbB5WRdhNF7WLZU52xW'},
#      'href': 'https://api.spotify.com/v1/albums/75qfbB5WRdhNF7WLZU52xW',
#      'id': '75qfbB5WRdhNF7WLZU52xW',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2730c6ec503bd5bbc6608167941',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e020c6ec503bd5bbc6608167941',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048510c6ec503bd5bbc6608167941',
#        'width': 64}],
#      'name': 'Danger Zone',
#      'release_date': '2007-06-26',
#      'release_date_precision': 'day',
#      'total_tracks': 16,
#      'type': 'album',
#      'uri': 'spotify:album:75qfbB5WRdhNF7WLZU52xW'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1DisOtNFBsfGAuifnt4o8j'},
#       'href': 'https://api.spotify.com/v1/artists/1DisOtNFBsfGAuifnt4o8j',
#       'id': '1DisOtNFBsfGAuifnt4o8j',
#       'name': 'Chino Grande',
#       'type': 'artist',
#       'uri': 'spotify:artist:1DisOtNFBsfGAuifnt4o8j'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/4a8TMzvDnszW2iJbqjXvcr'},
#       'href': 'https://api.spotify.com/v1/artists/4a8TMzvDnszW2iJbqjXvcr',
#       'id': '4a8TMzvDnszW2iJbqjXvcr',
#       'name': 'Travie',
#       'type': 'artist',
#       'uri': 'spotify:artist:4a8TMzvDnszW2iJbqjXvcr'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/4Byc3x9CcT699ZmORPccck'},
#       'href': 'https://api.spotify.com/v1/artists/4Byc3x9CcT699ZmORPccck',
#       'id': '4Byc3x9CcT699ZmORPccck',
#       'name': 'Midget Loco',
#       'type': 'artist',
#       'uri': 'spotify:artist:4Byc3x9CcT699ZmORPccck'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/4wMWhQQx82agVd7osP1hRT'},
#       'href': 'https://api.spotify.com/v1/artists/4wMWhQQx82agVd7osP1hRT',
#       'id': '4wMWhQQx82agVd7osP1hRT',
#       'name': 'Trouble of Brown Side',
#       'type': 'artist',
#       'uri': 'spotify:artist:4wMWhQQx82agVd7osP1hRT'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/7sgVAztHMVXGT4XiczZb6F'},
#       'href': 'https://api.spotify.com/v1/artists/7sgVAztHMVXGT4XiczZb6F',
#       'id': '7sgVAztHMVXGT4XiczZb6F',
#       'name': 'Baby Jokes',
#       'type': 'artist',
#       'uri': 'spotify:artist:7sgVAztHMVXGT4XiczZb6F'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/2MSULrgm9zdQfT93lgw4cE'},
#       'href': 'https://api.spotify.com/v1/artists/2MSULrgm9zdQfT93lgw4cE',
#       'id': '2MSULrgm9zdQfT93lgw4cE',
#       'name': 'Lil Tripper',
#       'type': 'artist',
#       'uri': 'spotify:artist:2MSULrgm9zdQfT93lgw4cE'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 290546,
#     'explicit': True,
#     'external_ids': {'isrc': 'USPRZ0810308'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4EeCMt2dbO1GOU19sEAJsf'},
#     'href': 'https://api.spotify.com/v1/tracks/4EeCMt2dbO1GOU19sEAJsf',
#     'id': '4EeCMt2dbO1GOU19sEAJsf',
#     'is_local': False,
#     'name': 'Danger Zone',
#     'popularity': 22,
#     'preview_url': 'https://p.scdn.co/mp3-preview/de28f48e491c98bea3b99c7d11fc2a09abc15107?cid=dd1e7da8e4924986931df06f52c0ab26',
#     'track_number': 4,
#     'type': 'track',
#     'uri': 'spotify:track:4EeCMt2dbO1GOU19sEAJsf'}],
#   'limit': 20,
#   'next': 'https://api.spotify.com/v1/search?query=Danger+Zone&type=track&offset=20&limit=20',
#   'offset': 0,
#   'previous': None,
#   'total': 3171}}

# %%
#spotify.get_artist("1hCkSJcXREhrodeIHQdav8")

# %%
#access_token = spotify.access_token

# %%
headers = {
    "Authorization":f"Bearer {access_token}"
}
endpoint = "https://api.spotify.com/v1/search"
data = urlencode({"q":"time", "type": "track"})
print(data)

lookup_url = f"{endpoint}?{data}"
print(lookup_url)
r = requests.get(lookup_url, headers=headers)
print(r.status_code)

# %%
r.json()

# %%
data = urlencode({"q":"A Lannister Always pays his debts", "type": "track"})
lookup_url = f"{endpoint}?{data}"
r = requests.get(lookup_url, headers=headers)
r.json()

# %%
#client_creds = f"{client_id}:{client_secret}"
#type(client_creds)

# %%
#client_creds.encode() #turn str into bytes, .decode() turns it back

# %%
#client_creds_b64 = base64.b64encode(client_creds.encode()) #encodes credentials and changes type to bytes
#type(client_creds_b64)

# %%
#token_url = "https://accounts.spotify.com/api/token"
#method = "POST"
#token_data = {
 #   "grant_type":"client_credentials"
#}
#token_headers = {
 #   "Authorization": f"Basic {client_creds_b64.decode()}" #<base64 encoded client_id:client_secret>
#}

# %%
#r = requests.post(token_url, data=token_data, headers= token_headers)
#print(r.json())
#valid_request = r.status_code in range (200,299)
